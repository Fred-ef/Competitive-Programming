# %%
import sys
import matplotlib.pyplot as plt

# %%
import seaborn as sns
import pandas as pd

# %%
result_path = "results.csv"
results_df = pd.read_csv(result_path)

# %%
results_df[(results_df.Method == "Linear") & (results_df.n == 32768)]
# Out:
#      Method      n     k  elapsed
# 204  Linear  32768     8   478700
# 209  Linear  32768    16   442200
# 214  Linear  32768    32   501100
# 219  Linear  32768    64   475000
# 224  Linear  32768   128   549800
# 229  Linear  32768   256   460700
# 234  Linear  32768   512   404900
# 239  Linear  32768  1024   440800

# %%
results_df[(results_df.Method == "Heap") & (results_df.n == 32768)]
# Out:
#     Method      n     k  elapsed
# 202   Heap  32768     8  2041800
# 207   Heap  32768    16  1772100
# 212   Heap  32768    32  1186200
# 217   Heap  32768    64  1112600
# 222   Heap  32768   128  1162600
# 227   Heap  32768   256   782200
# 232   Heap  32768   512   620100
# 237   Heap  32768  1024   662600

# %%
sns.set_style('darkgrid')
sns.set_context('notebook')
for curr_n in pd.unique(results_df['n']):
    plt.title(f"n = {curr_n}")
    curr_df = results_df[results_df.n == curr_n]
    ax = sns.scatterplot(x="k", y="elapsed", hue="Method", data=curr_df)
    ax.legend(bbox_to_anchor=(1.5, 1.05))
    plt.show()
